# %%
import pandas as pd
df = pd.read_csv('inmuebles_detallado_20260218.csv')
df.head(10)
# Out:
#             Tipo Operación      Precio  Administración  Niveles  Habitaciones  \
# 0    Apartamento     Venta 535,000,000         680,000        4             3
# 1        Oficina  Arriendo   1,500,000         362,000        3             0
# 2    Apartamento     Venta 530,000,000         280,000        0             3
# 3    Apartamento     Venta 315,000,000         343,000        2             1
# 4           Casa     Venta 230,000,000             NaN        1             3
# 5           Casa  Arriendo     650,000             NaN        0             2
# 6  Apartaestudio     Venta 426,000,000       1,000,000        0             1
# 7           Casa  Arriendo   2,700,000             NaN        0             4
# 8    Apartamento  Arriendo     900,000             NaN        0             2
# 9          Local  Arriendo  13,000,000             NaN        0             0
#
#    Baños  Parqueaderos  Área Construida  Área Lote                 Barrio  \
# ...

# %%
#df.drop(index=9, inplace=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)

# %%
df=df[df['Operación'].str.lower() == 'venta']
df
# Out:
#                Tipo Operación        Precio  Administración  Niveles  \
# 0       Apartamento     Venta   535,000,000         680,000        4
# 2       Apartamento     Venta   530,000,000         280,000        0
# 3       Apartamento     Venta   315,000,000         343,000        2
# 4              Casa     Venta   230,000,000             NaN        1
# 6     Apartaestudio     Venta   426,000,000       1,000,000        0
# ...             ...       ...           ...             ...      ...
# 2212           Casa     Venta   500,000,000             NaN        0
# 2214    Apartamento     Venta   620,000,000         382,000        8
# 2217        Oficina     Venta    85,000,000         182,000        0
# 2218          Local     Venta 2,700,000,000             NaN        0
# 2219           Casa     Venta   450,000,000             NaN        0
#
#       Habitaciones  Baños  Parqueaderos  Área Construida  Área Lote  \
# 0                3      3             0              119        119
# ...

# %% [markdown]
# para el analisis solo trabajaremos con cucuta por que es un proyecto local

# %%
df=df[df['Ciudad'].str.lower() == 'cúcuta'] 
df
# Out:
#                Tipo Operación        Precio  Administración  Niveles  \
# 13             Lote     Venta   200,000,000         376,100        0
# 27    Apartaestudio     Venta   140,000,000         222,000        0
# 29      Apartamento     Venta   340,000,000         267,000        0
# 31             Casa     Venta   185,000,000             NaN        0
# 46      Apartamento     Venta   300,000,000         160,000        0
# ...             ...       ...           ...             ...      ...
# 2202           Casa     Venta   220,000,000             NaN        0
# 2211           Lote     Venta 1,000,000,000             NaN        0
# 2212           Casa     Venta   500,000,000             NaN        0
# 2217        Oficina     Venta    85,000,000         182,000        0
# 2219           Casa     Venta   450,000,000             NaN        0
#
#       Habitaciones  Baños  Parqueaderos  Área Construida  Área Lote  \
# 13               0      0             0                0        168
# ...

# %%
for col in df.columns:
    count_vacio = (df[col] == '').sum()
    count_espacio = (df[col] == ' ').sum()

    if count_vacio > 0 or count_espacio > 0:
        print(col)
        if count_vacio > 0:
            print(f"  Vacíos (''): {count_vacio}")
        if count_espacio > 0:
            print(f"  Espacios (' '): {count_espacio}")
    else:
        print(f"{col} 0 vacíos ni espacios")
# Out:
# Tipo 0 vacíos ni espacios
# Operación 0 vacíos ni espacios
# Precio 0 vacíos ni espacios
# Administración 0 vacíos ni espacios
# Niveles 0 vacíos ni espacios
# Habitaciones 0 vacíos ni espacios
# Baños 0 vacíos ni espacios
# Parqueaderos 0 vacíos ni espacios
# Área Construida 0 vacíos ni espacios
# Área Lote 0 vacíos ni espacios
# Barrio 0 vacíos ni espacios
# Estrato 0 vacíos ni espacios
# Ciudad 0 vacíos ni espacios

# %%
print(df.isna().sum().sort_values(ascending=False))
# Out:
# Administración     370
# Tipo                 0
# Operación            0
# Precio               0
# Niveles              0
# Habitaciones         0
# Baños                0
# Parqueaderos         0
# Área Construida      0
# Área Lote            0
# Barrio               0
# Estrato              0
# Ciudad               0
# dtype: int64

# %%
print(df['Administración'].isna().sum())
df['Administración'] = df['Administración'].fillna(0)
print(df['Administración'].isna().sum())
# Out:
# 370
# 0
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_15680\1982407552.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Administración'] = df['Administración'].fillna(0)

# %%
for col in df.columns:
    print(f"\nConteo en columna: {col}")
    print(df[col].value_counts(dropna=False).sort_index())
# Out:
# Conteo en columna: Tipo
# Tipo
# Apartaestudio      10
# Apartamento       206
# Bodega             15
# Casa              269
# Casa campestre      1
# Casa-local          9
# Casalote            7
# Consultorio         4
# Edificio            5
# Hotel               3
# Local              37
# Lote               36
# Oficina            13
# Name: count, dtype: int64
#
# Conteo en columna: Operación
# Operación
# Venta    615
# Name: count, dtype: int64
#
# Conteo en columna: Precio
# Precio
# 23,000,000       1
# 30,000,000       1
# 33,000,000       1
# 50,000,000       1
# 59,000,000       1
#                 ..
# 4,106,650,000    1
# 5,308,800,000    1
# 5,975,000,000    1
# 6,000,000,000    1
# 8,000,000,000    1
# Name: count, Length: 155, dtype: int64
#
# Conteo en columna: Administración
# Administración
# 0            370
# 50,000        11
# 53,000         2
# 60,000         3
# 70,000         8
#             ...
# 950,000        2
# 1,050,000      1
# 1,100,000      1
# ...

# %%
import matplotlib.pyplot as plt

df.boxplot(column='Precio')
plt.ylabel('Precio')
plt.title('Boxplot de la columna Precio')
plt.show()

# %%
limite = df['Precio'].quantile(0.87)
df_filtrado = df[df['Precio'] <= limite]

plt.figure()
plt.boxplot(df_filtrado['Precio'])
plt.title('Boxplot Precio sin outliers extremos')
plt.ylabel('Precio')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

# Quitar nulos
precios = df_filtrado['Precio'].dropna()

# Histograma normalizado
plt.hist(precios, bins=50, density=True)

# Crear curva KDE
kde = gaussian_kde(precios)
x = np.linspace(precios.min(), precios.max(), 1000)
plt.plot(x, kde(x))

plt.title("Distribución de Precios")
plt.xlabel("Precio")
plt.ylabel("Densidad")
plt.show()

# %% [markdown]
# -Distribución asimétrica (sesgo a la derecha)
# -La curva naranja muestra claramente una asimetría positiva.
# -La mayor concentración está en precios bajos–medios.
# -Hay una cola larga hacia la derecha (propiedades caras).
#
# -Esto significa que:
# La mayoría del mercado está en rangos accesibles/intermedios. El pico de la campana está aproximadamente entre:150M – 250M

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
# Ver el 13% con precios más elevados

import pandas as pd

# Calcular el percentil 87
limite_87 = df['Precio'].quantile(0.87)

# Filtrar el 13% superior
top_10 = df[df['Precio'] >= limite_87].sort_values(by='Precio', ascending=False)

# Mostrar información básica
print("Umbral del percentil 87:", limite_87)
print("Cantidad de registros en el 13% superior:", len(top_10))
top_10.head(10)
# Out:
# Umbral del percentil 87: 750000000.0
# Cantidad de registros en el 13% superior: 87
#           Tipo Operación        Precio  Administración  Niveles  Habitaciones  \
# 1033    Bodega     Venta 8,000,000,000               0        2             0
# 1564     Hotel     Venta 6,000,000,000               0        2            46
# 1831      Lote     Venta 5,975,000,000               0        0             0
# 2140      Lote     Venta 5,308,800,000               0        0             0
# 1947      Lote     Venta 4,106,650,000               0        0             0
# 2043     Local     Venta 4,000,000,000               0        0             0
# 1438    Bodega     Venta 3,600,000,000               0        0             0
# 958   Casalote     Venta 3,500,000,000               0        0             1
# 2129  Edificio     Venta 3,200,000,000               0        0             0
# 1418      Casa     Venta 3,200,000,000               0        0             0
#
# ...

# %%
df.drop(index=1438, inplace=True)
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_15680\2504865910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=1438, inplace=True)

# %%
df['Tipo'].value_counts().head(7)
# Out:
# Tipo
# Casa             269
# Apartamento      206
# Local             37
# Lote              36
# Bodega            14
# Oficina           13
# Apartaestudio     10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
df['Tipo'].value_counts().plot(kind='bar')
plt.title('Distribución de Tipos de Inmuebles')
plt.xlabel('Tipo de Inmueble')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# hay mucha mas cantidad de casas y apartamento que en los demas tipo esto nos indica que es hay mas variedad para los gustos y mas importante variedad de precios

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
medianastipo = df.groupby("Tipo")["Precio"].median()
medianastipo.sort_values(ascending=True).plot(kind='bar')
plt.title('Precios por mediana de Tipo de Inmueble')
plt.xlabel('Tipo de Inmueble')
plt.ylabel('Precio Promedio')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ahora la casa y el apartamento ocupa el 4to y el 7to puesto como el promedio de inmueble mas baratos

# %%
plt.figure(figsize=(8,2))

df_casas = df[df['Tipo'] == 'Casa']
precioporbarrios = df_casas.groupby('Barrio')['Precio'].median()

precioporbarrios=precioporbarrios[precioporbarrios < 210000000]



precioporbarrios.sort_values(ascending=True).plot(kind='bar')




plt.xticks(rotation=90)

# Líneas horizontales punteadas
plt.grid(axis='y', linestyle='--')
plt.title('Precios por mediana de casas por barrio')
plt.xlabel('barrio')
plt.ylabel('Precio medio')
plt.show()

# %%
plt.figure(figsize=(10,1.5))

df_apto = df[df['Tipo'] == 'Apartamento']
precioporbarrios = df_apto.groupby('Barrio')['Precio'].median()

precioporbarrios=precioporbarrios[precioporbarrios < 150000000]

precioporbarrios.sort_values(ascending=True).plot(kind='bar')

plt.xticks(rotation=75)

# Líneas horizontales punteadas
plt.grid(axis='y', linestyle='--')
plt.title('Precios por mediana de apartamentos por barrio')
plt.xlabel('barrio')
plt.ylabel('Precio medio')
plt.show()

# %%
df_lote = df[df['Tipo'] == 'Lote']

# %%
df = df.copy()
# Asegurar que sean numéricos
df['Precio'] = pd.to_numeric(df['Precio'], errors='coerce')
df['Estrato'] = pd.to_numeric(df['Estrato'], errors='coerce')



# Agrupar ambas columnas
resumen = df_lote.groupby('Barrio').agg({
    'Precio': 'median',
    'Estrato': 'mean'
})

# Ordenar por precio
resumen = resumen.sort_values('Precio')
color_map = {
    1: '#d73027',
    2: '#fc8d59',
    3: "#ecd48f",
    4: "#baf5b5",
    5: "#69ee03",
    6: "#006411"
}

# Redondear estrato promedio
resumen['Estrato_redondeado'] = resumen['Estrato'].round()

# Asignar colores
colores = resumen['Estrato_redondeado'].map(color_map)

plt.figure(figsize=(10,3))
plt.bar(resumen.index, resumen['Precio'], color=colores)

plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--')
plt.title("Mediana precio de lote por barrio (color por estrato)")

plt.xlabel('barrio')
plt.ylabel('Precio mediana')
from matplotlib.patches import Patch

# Crear elementos de leyenda
legend_elements = [
    Patch(facecolor=color_map[estrato], label=f'Estrato {estrato}')
    for estrato in sorted(color_map.keys())
]

plt.legend(handles=legend_elements, title="Estrato", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df = df.copy()
# Asegurar que sean numéricos
df['Precio'] = pd.to_numeric(df['Precio'], errors='coerce')
df['Estrato'] = pd.to_numeric(df['Estrato'], errors='coerce')


# Agrupar ambas columnas
resumen = df_casas.groupby('Barrio').agg({
    'Precio': 'median',
    'Estrato': 'mean'
})

# Ordenar por precio
resumen = resumen.sort_values('Precio')
color_map = {
    1: '#d73027',
    2: '#fc8d59',
    3: "#ecd48f",
    4: "#baf5b5",
    5: "#69ee03",
    6: "#006411"
}

# Redondear estrato promedio
resumen['Estrato_redondeado'] = resumen['Estrato'].round()

# Asignar colores
colores = resumen['Estrato_redondeado'].map(color_map)

plt.figure(figsize=(22,3))
plt.bar(resumen.index, resumen['Precio'], color=colores)

plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--')
plt.title("Mediana precio de casa por barrio (color por estrato)")

plt.xlabel('barrio')
plt.ylabel('Precio mediana')
from matplotlib.patches import Patch

# Crear elementos de leyenda
legend_elements = [
    Patch(facecolor=color_map[estrato], label=f'Estrato {estrato}')
    for estrato in sorted(color_map.keys())
]

plt.legend(handles=legend_elements, title="Estrato", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df = df.copy()
# Asegurar que sean numéricos
df['Precio'] = pd.to_numeric(df['Precio'], errors='coerce')
df['Estrato'] = pd.to_numeric(df['Estrato'], errors='coerce')


# Agrupar ambas columnas
resumen = df_apto.groupby('Barrio').agg({
    'Precio': 'median',
    'Estrato': 'mean'
})

# Ordenar por precio
resumen = resumen.sort_values('Precio')
color_map = {
    1: '#d73027',
    2: '#fc8d59',
    3: "#ecd48f",
    4: "#baf5b5",
    5: "#69ee03",
    6: "#006411"
}

# Redondear estrato promedio
resumen['Estrato_redondeado'] = resumen['Estrato'].round()

# Asignar colores
colores = resumen['Estrato_redondeado'].map(color_map)

plt.figure(figsize=(20,3))
plt.bar(resumen.index, resumen['Precio'], color=colores)

plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--')
plt.title("Mediana precio de apartamento por barrio (color por estrato)")

plt.xlabel('barrio')
plt.ylabel('Precio mediana')
from matplotlib.patches import Patch

# Crear elementos de leyenda
legend_elements = [
    Patch(facecolor=color_map[estrato], label=f'Estrato {estrato}')
    for estrato in sorted(color_map.keys())
]

plt.legend(handles=legend_elements, title="Estrato", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df['Estrato'].value_counts()
# Out:
# Estrato
# 3    255
# 4    192
# 2     99
# 5     51
# 1     10
# 6      6
# 7      1
# Name: count, dtype: int64

# %% [markdown]
# para la siguiente conclusion es mejor no filtrar vemos que el barrio mas carato para comprar

# %%
resultado = df.pivot_table(
    values="Precio",
    index="Barrio",
    columns="Tipo",
    aggfunc="median"
)

print("\nMediana por barrio (Casas vs Lotes):")

resultado['ganancia'] = resultado['Casa'] - resultado['Lote']
resultado=resultado[['Casa', 'Lote', 'ganancia']]
resultado=resultado.sort_values(by=['ganancia','Casa'], ascending=False)
resultado.head(15)
# Out:
# Mediana por barrio (Casas vs Lotes):
# Tipo                                      Casa          Lote       ganancia
# Barrio
# Barrio Blanco                    1,200,000,000   680,000,000    520,000,000
# San Pedro - Portico                735,000,000   230,000,000    505,000,000
# Ceiba II                           450,000,000   360,000,000     90,000,000
# El Contento                        160,000,000    84,500,000     75,500,000
# Bocono                             285,000,000   350,000,000    -65,000,000
# Villa Del Rosario                  195,000,000   335,000,000   -140,000,000
# Guaimaral                          435,000,000   600,000,000   -165,000,000
# El Llano                           380,000,000   950,000,000   -570,000,000
# Niza                               420,000,000 1,100,000,000   -680,000,000
# Santander                          185,000,000 1,336,615,000 -1,151,615,000
# Popular                            575,000,000 5,975,000,000 -5,400,000,000
# ...

# %%
df[(df['Tipo']=='Lote') & (df['Barrio']=='Popular')].sort_values(by='Precio', ascending=False).head(10)
# Out:
#       Tipo Operación        Precio  Administración  Niveles  Habitaciones  \
# 1831  Lote     Venta 5,975,000,000               0        0             0
#
#       Baños  Parqueaderos  Área Construida  Área Lote   Barrio  Estrato  \
# 1831      0             0                0      2,390  Popular        4
#
#       Ciudad
# 1831  Cúcuta
